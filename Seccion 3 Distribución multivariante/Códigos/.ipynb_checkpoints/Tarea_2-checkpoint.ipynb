# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import StandardScaler

# %%
datos = pd.read_csv('../Datos/companies79.csv', index_col=0)

# %%
datos.head()
# Out:
#                              V1     V2    V3     V4      V5      V6    V7  \
# 1                  BellAtlantic  19788  9084  10636  1092.9  2576.8  79.4
# 2            ContinentalTelecom   5074  2557   1892   239.9   578.3  21.9
# 3         AmericanElectricPower  13621  4848   4572   485.0   898.9  23.4
# 4              BrooklynUnionGas   1117  1038    478    59.7    91.7   3.8
# 5  CentralIllinoisPublicService   1633   701    679    74.3   135.9   2.8
#
#               V8
# 1  Communication
# 2  Communication
# 3         Energy
# 4         Energy
# 5         Energy

# %%
datos.dtypes
# Out:
# V1     object
# V2      int64
# V3      int64
# V4      int64
# V5    float64
# V6    float64
# V7    float64
# V8     object
# dtype: object

# %%
xf = datos.iloc[:,1:7]

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data = xf)
plt.show()

# %%
scaler = StandardScaler()
xf_scal = scaler.fit_transform(xf.values)
xf_scal_df = pd.DataFrame(xf_scal, columns=xf.columns, index=xf.index)

# %%
xf_scal_df.head()
# Out:
#          V2        V3        V4        V5        V6        V7
# 1  1.521926  0.704123  0.655840  1.065291  1.806451  0.652200
# 2 -0.095237 -0.232706 -0.122665 -0.036676  0.122078 -0.244911
# 3  0.844133  0.096124  0.115944  0.279962  0.392285 -0.221508
# 4 -0.530137 -0.450731 -0.248558 -0.269471 -0.288038 -0.527306
# 5 -0.473426 -0.499101 -0.230662 -0.250610 -0.250786 -0.542908

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data = xf_scal_df)
plt.show()

# %%
xf_sector['V8'].value_counts()
# Out:
# Finance           17
# Energy            15
# Retail            10
# Manufacturing     10
# HiTech             8
# Other              7
# Transportation     6
# Medical            4
# Communication      2
# Name: V8, dtype: int64

# %%
xf_sector = pd.concat([xf_scal_df, datos['V8']], axis = 1)
#xf_sector.V8 = xf_sector.V8.astype('category')
plt.figure(figsize=(20,8))
xf_sector.boxplot(by="V8", figsize=(24,12))
plt.xticks(rotation = 90)
plt.tight_layout()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
xf_scal_df.hist(edgecolor = 'black', linewidth = 1.2, grid = False, figsize=(20,8))
plt.show()

# %%
for v in xf_scal_df.columns.values:
    sns.distplot(xf[v]).kdeplot(kernel = 'gau')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-f84444a2a79e> in <module>
#       1 for v in xf_scal_df.columns.values:
# ----> 2     sns.distplot(xf[v]).kdeplot(kernel = 'gau')
#       3     plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'kdeplot'

# %%
xf_reducido = xf_sector[xf_sector['V2'] < 1]

# %%
from pandas.plotting import scatter_matrix
# color_function = {0:'blue', 1:'red'}
# colors = df[].map(lambda x :color_function.get(x))

sm = scatter_matrix(xf_reducido, figsize = (15,15)) #alpha
plt.show()

# %%
sns.pairplot(xf_sector, hue = 'V8', diag_kind='kde', diag_kws=dict(shade = True), height=1.5)
